# %%
import os
from aip import AipImageClassify

class ImageBatchProcessor:
    # 初始化密钥
    def __init__(self, app_id, api_key, secret_key, folder_path):
        self.client = AipImageClassify(app_id, api_key, secret_key)
        self.folder_path = folder_path 
        self.image_exts = (".jpg", ".jpeg", ".png", ".bmp")

    # 读取单个文件
    def get_file_content(self, file_path):
        with open(file_path, "rb") as fp:
            return fp.read()
    
    # 处理单张图片
    def recognize_image(self, file_path):
        img_data = self.get_file_content(file_path)
        return self.client.advancedGeneral(img_data)

    # 处理一组图片
    def process_all_images(self):
        # 遍历文件夹下的所有文件
        for file_name in os.listdir(self.folder_path):
            # 拼接路径
            file_path = os.path.join(self.folder_path, file_name)
            
            # 只处理允许格式图片
            if file_name.lower().endswith(self.image_exts):
                print(f"正在处理：{file_name}")
                result = self.recognize_image(file_path)
                print("识别结果：", result)


APP_ID = "7615563"
API_KEY = "9ddxioo3nfDbWV9mSJ3FPcA5"
SECRET_KEY = "o24YZIBahSKRGbkOFhvqfzNcifzAKmdw"

# 图库路径
folder_path = r"D:\Mar\ml\IA\image"

# 创建对象
processor = ImageBatchProcessor(APP_ID, API_KEY, SECRET_KEY, folder_path)

# 开始批量处理
processor.process_all_images()
# Out:
# 正在处理：dish.png
# 识别结果： {'result': [{'score': 0.785076, 'root': '商品-食物', 'keyword': '京酱肉丝'}, {'score': 0.618113, 'root': '商品-食物', 'keyword': '葱爆羊肉'}, {'score': 0.453776, 'root': '商品-食物', 'keyword': '鱼香肉丝'}, {'score': 0.289925, 'root': '商品-食物', 'keyword': '茶树菇'}, {'score': 0.126766, 'root': '商品-食物', 'keyword': '香辣鸭舌'}], 'result_num': 5, 'log_id': 2042157829315650427}
# 正在处理：dog.png
# 识别结果： {'result': [{'score': 0.468774, 'root': '动物-狗', 'keyword': '小狗'}, {'score': 0.349167, 'root': '动物-其他', 'keyword': '鸟类'}, {'score': 0.235244, 'root': '动物-狗', 'keyword': '贵妇狗'}, {'score': 0.130199, 'root': '动物-狗', 'keyword': '香槟色贵宾'}, {'score': 0.011725, 'root': '动物-哺乳动物', 'keyword': '贵宾犬/贵妇犬'}], 'result_num': 5, 'log_id': 2042157833194510612}
# 正在处理：huge.png
# 识别结果： {'result': [{'score': 0.817144, 'root': '公众人物', 'keyword': '胡歌'}, {'score': 0.643049, 'root': '人物-人物特写', 'keyword': '人物特写'}, {'score': 0.414673, 'root': '人物-人物特写', 'keyword': '人脸'}, {'score': 0.205724, 'root': '人物-人物特写', 'keyword': '美女'}, {'score': 0.018045, 'root': '人物活动-人物特写', 'keyword': '男人'}], 'result_num': 5, 'log_id': 2042157837976334827}
# 正在处理：SUV.png
# 识别结果： {'result': [{'score': 0.98431, 'root': '交通工具-汽车', 'keyword': '轿车'}, {'score': 0.79437, 'root': 'Logo', 'keyword': '吉普'}, {'score': 0.445539, 'root': '交通工具-汽车', 'keyword': 'SUV'}, {'score': 0.228098, 'root': '交通工具-汽车', 'keyword': '汽车'}, {'score': 0.002161, 'root': '交通工具-汽车', 'keyword': '跑车'}], 'result_num': 5, 'log_id': 2042157847774298212}
# 正在处理：yumi.png
# 识别结果： {'result': [{'score': 0.865735, 'root': '商品-食品', 'keyword': '玉米'}, {'score': 0.680351, 'root': '植物-其它', 'keyword': '玉米棒'}, {'score': 0.472693, 'root': '植物-其它', 'keyword': '甜玉米'}, {'score': 0.210228, 'root': '植物-葫芦科', 'keyword': '苦瓜'}, {'score': 0.030457, 'root': '植物-其它', 'keyword': '甜糯玉米'}], 'result_num': 5, 'log_id': 2042157853594488838}
